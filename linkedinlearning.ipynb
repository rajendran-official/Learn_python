# %% [markdown]
# <a href="https://colab.research.google.com/github/rajendran-official/Learn_python/blob/Python-Basics/linkedinlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BASIC DATATYPES**
#
# Define a varialble

# %%
x=5
print(x)
# Out:
# 5

# %%
x
# Out:
# 5

# %%
name='Ryan'#string
type(name)
type(x)
# Out:
# int

# %% [markdown]
# **Numbers**

# %%
type(1.5)
# Out:
# float

# %%
1.2345689

# %%
12233434.9

# %%
type(2j)
# Out:
# complex

# %%
1j*1j
# Out:
# (-1+0j)

# %% [markdown]
# **Strings**

# %%
'String  1 ' +  'String 2'
# Out:
# 'String  1 String 2'

# %%
'1'+'1'
# Out:
# '11'

# %% [markdown]
# **Booleans**

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
true=True

# %%
1==1
# Out:
# True

# %%
1==2
# Out:
# False

# %% [markdown]
# **DATA STRUCTURES**
#
# Lists

# %%
My_list =[1,2,3,4]
print(My_list)
# Out:
# [1, 2, 3, 4]

# %%
my_list = ['list','of','strings']
print(my_list)
# Out:
# ['list', 'of', 'strings']

# %%
my_list = [1,'list',False,[]]
print(my_list)
# Out:
# [1, 'list', False, []]

# %%
my_list = [[1,2,3],[False,True],[]]
print(my_list)
# Out:
# [[1, 2, 3], [False, True], []]

# %%
len(my_list)
# Out:
# 3

# %% [markdown]
# **Sets**

# %%
my_set ={1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(my_set)
# Out:
# set

# %%
len(my_set)
# Out:
# 5

# %%
my_set={1,1,2,2}
len(my_set)
print(my_set)
# Out:
# {1, 2}

# %%
[1,2]==[2,1]
# Out:
# False

# %%
{1,2,3}=={3,2,1,1,1}
# Out:
# True

# %% [markdown]
# **Tuples**

# %%
my_tuple =(1,2,3)

# %%
len(my_tuple)
# Out:
# 3

# %%
(1,2)==(2,1)
# Out:
# False

# %%
my_list.append(6)
print(my_list)
# Out:
# [[1, 2, 3], [False, True], [], 6]

# %%
my_tuple.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3420063398.py in <cell line: 0>()
# ----> 1 my_tuple.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# **Dictonaries**

# %%
my_dictionary={'apple':'A red fruit','bear':'A scary animal','apple':'Sometimes a green fruit'}
print(my_dictionary)
my_dictionary['apple']
# Out:
# {'apple': 'Sometimes a green fruit', 'bear': 'A scary animal'}
# 'Sometimes a green fruit'

# %% [markdown]
# **Arthmetic Operators**

# %%
1+1
# Out:
# 2

# %%
4+5
# Out:
# 9

# %%
5**2
# Out:
# 25

# %%
20/5
# Out:
# 4.0

# %%
20/6
# Out:
# 3.3333333333333335

# %%
#modulus operator gives remainder
20%6
# Out:
# 2

# %% [markdown]
# **Arthmetic Operator with Strings**

# %%
'string 1 ' + 'string 2'
# Out:
# 'string 1 string 2'

# %%
'string 1 ' * 4
# Out:
# 'string 1 string 1 string 1 string 1 '

# %%
'1' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1256546886.py in <cell line: 0>()
# ----> 1 '1' + 4
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Comparison. Logical, Membership Operators**
#
# **comparison Operators**

# %%
True== True
# Out:
# True

# %%
4 <5
# Out:
# True

# %%
5>2
# Out:
# True

# %%
5>=2
# Out:
# True

# %%
5<=5
# Out:
# True

# %% [markdown]
# **Logical Operators(and, or, not)**

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# Membership Operators

# %%
1 in [1,2,3,4,5]
# Out:
# True

# %%
10 in [1,2,3,4,5]
# Out:
# False

# %%
10 not in [1,2,3,4,5]
# Out:
# True

# %%
'cat' in 'my pet cat'
# Out:
# True

# %%
'cat' not in 'my pet cat'
# Out:
# False

# %% [markdown]
# **Control FLow**
#
# **if /else statements**

# %%
a= True
if a:# -->( : )indent belongs to if /else
  print('It is true!')
  print('Also print this')
else:
    print('It is false!')
    print('Also print this')
# Out:
# It is true!
# Also print this

# %%
from logging import info
a= True
b= True
c= False
if a:# -->( : )indent belongs to if /else
  print('It is true!')
  print('Also print this')
  if b:
    print('Both are true')
    if c:
      print('All three are true')
else:
    print('It is false!')
    print('Also print this')
# Out:
# It is true!
# Also print this
# Both are true

# %% [markdown]
# ***For loops***

# %%
a=[1,2,3,4,5]
for number in a:
  print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
4 in a
# Out:
# True

# %% [markdown]
# ***While Loops***

# %%
a = 0
while a < 5:
      print(a)
      a = a+1
# Out:
# 0
# 1
# 2
# 3
# 4
